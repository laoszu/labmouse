# %%
import json
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from PIL import Image
import numpy as np
import pandas as pd
import random

# %%
def display_sample(json_path, data_path, limit=2000):
    with open(json_path) as json_file:
        data = json.load(json_file)

    filenames = list(data.keys())
    n_image = random.randint(0, 2000)
    filename = filenames[n_image]
    box = data[filename][0]['Boundingbox']
    print(data[filename])

    box = {key: int(value) for key, value in box.items()}
    print(box)

    img = np.asarray(Image.open(f"{data_path}/{filename}"))
    plt.title(filename)
    plt.imshow(img)

    ax = plt.gca()
    rect = Rectangle((box['x'], box['y']), box['w'] - box['x'], box['h'] - box['y'], linewidth=1, edgecolor='r', facecolor='none')
    ax.add_patch(rect)

# %%
display_sample("data/face_detection_data.json", "Face_detection")
# Out:
# [{'AnimalNumber': '5', 'Boundingbox': {'x': '859', 'y': '462', 'w': '1365', 'h': '952'}}]
# {'x': 859, 'y': 462, 'w': 1365, 'h': 952}

# %%
display_sample("data/eyes_detection_data.json", "Eyes_detection", 1000)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 display_sample("data/eyes_detection_data.json", "Eyes_detection")
#
# Cell In[61], line 7, in display_sample(json_path, data_path)
#       5 filenames = list(data.keys())
#       6 n_image = random.randint(0, 2000)
# ----> 7 filename = filenames[n_image]
#       8 box = data[filename][0]['Boundingbox']
#       9 print(data[filename])
#
# IndexError: list index out of range
